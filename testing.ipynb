# %%
import json

from weatherflow4py.api import WeatherFlowRestAPI

# %%
token = "a011d75e-486a-4f09-bd2c-c07b796528b9"

# %%
api = WeatherFlowRestAPI(token)

# %%
forecast = await api.async_get_forecast(82443)

# %%
obs = await api.async_get_observation(82443)

# %%
# ?api.async_get_forecast
# Out:
# Signature: api.async_get_forecast(station_id: int) -> weatherflow4py.models.rest.forecast.WeatherDataForecastREST
# Docstring:
# Gets the forecast for a given station_id.
#
# Args:
#     station_id (int): The ID of the station_id.
#
# Raises:
#     ClientResponseError: If there is a client response error.
# File:      ~/projects/mcp-server-tempest/.venv/lib/python3.13/site-packages/weatherflow4py/api.py
# Type:      method

# %%
with open("/Users/bdc/Downloads/forecast.json", "w") as f:
    json.dump(forecast.to_json(), f, indent=4)

# %%
station = await api.async_get_station(82443)

# %%
# Out:
# 1
